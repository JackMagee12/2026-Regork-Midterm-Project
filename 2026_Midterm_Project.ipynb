# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import bokeh.plotting as bp
from completejourney_py import get_data

# Load all datasets
data = get_data()

# Access transaction data
transactions = data["transactions"]
print(f"Loaded {len(transactions):,} transaction records")

# Basic analysis
top_products = (transactions
    .groupby('product_id')['sales_value']
    .sum()
    .sort_values(ascending=False)
    .head(10))
# Out:
# Loaded 1,469,307 transaction records

# %%
demographics = data["demographics"]
demographics.head()
# Out:
#    household_id    age     income home_ownership marital_status  \
# 0             1    65+     35-49K      Homeowner        Married
# 1          1001  45-54     50-74K      Homeowner      Unmarried
# 2          1003  35-44     25-34K           None      Unmarried
# 3          1004  25-34     15-24K           None      Unmarried
# 4           101  45-54  Under 15K      Homeowner        Married
#
#   household_size    household_comp kids_count
# 0              2  2 Adults No Kids          0
# 1              1   1 Adult No Kids          0
# 2              1   1 Adult No Kids          0
# 3              1   1 Adult No Kids          0
# 4              4     2 Adults Kids          2

# %%
products = data["products"]
products.head()
# Out:
#    product_id  manufacturer_id     department     brand      product_category  \
# 0       25671                2        GROCERY  National              FRZN ICE
# 1       26081                2  MISCELLANEOUS  National                  None
# 2       26093               69         PASTRY   Private                 BREAD
# 3       26190               69        GROCERY   Private  FRUIT - SHELF STABLE
# 4       26355               69        GROCERY   Private         COOKIES/CONES
#
#            product_type package_size
# 0   ICE - CRUSHED/CUBED        22 LB
# 1                  None         None
# 2  BREAD:ITALIAN/FRENCH         None
# 3           APPLE SAUCE        50 OZ
# 4     SPECIALTY COOKIES        14 OZ

# %%
transactions.head()
# Out:
#    household_id  store_id    basket_id  product_id  quantity  sales_value  \
# 0           900       330  31198570044     1095275         1         0.50
# 1           900       330  31198570047     9878513         1         0.99
# 2          1228       406  31198655051     1041453         1         1.43
# 3           906       319  31198705046     1020156         1         1.50
# 4           906       319  31198705046     1053875         2         2.78
#
#    retail_disc  coupon_disc  coupon_match_disc  week transaction_timestamp
# 0         0.00          0.0                0.0     1   2017-01-01 11:53:26
# 1         0.10          0.0                0.0     1   2017-01-01 12:10:28
# 2         0.15          0.0                0.0     1   2017-01-01 12:26:30
# 3         0.29          0.0                0.0     1   2017-01-01 12:30:27
# 4         0.80          0.0                0.0     1   2017-01-01 12:30:27
